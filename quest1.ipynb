# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
data=pd.read_csv("people.csv")
print("Dataset:\n\n",data)
data["follow"]=""
n=len(data)


ruleset(data)
print("\n\nDataset showing records which satisfy all rules:\n\n",data)

follow_count=data.follow.value_counts()
print(follow_count)
print("Number of records that satisfy all rules: ",follow_count[True])


data.plot(kind='bar', figsize=(12,6), title='Plot between numeric data of a row')
plt.show()

y=np.zeros(len(data['age']))
y=y+150

plt.figure(figsize=[9.0,7.0])
plt.plot([1,2,3,4,5],data['age'].values,'ro')
plt.plot([1,2,3,4,5],y,'b-')
plt.xticks([1,2,3,4,5])
plt.xlabel("Indices")
plt.ylabel("Age")
plt.show()
# Out:
# Dataset:
#
#     age agegroup  height   status  yearsmarried
# 0   21    adult     6.0   single            -1
# 1    2    child     3.0  married             0
# 2   18    adult     5.7  married            20
# 3  221  elderly     5.0  widowed             2
# 4   34    child    -7.0  married             3
#
#
# Dataset showing records which satisfy all rules:
#
#     age agegroup  height   status  yearsmarried follow
# 0   21    adult     6.0   single            -1   True
# 1    2    child     3.0  married             0   True
# 2   18    adult     5.7  married            20  False
# 3  221  elderly     5.0  widowed             2  False
# 4   34    child    -7.0  married             3  False
# False    3
# True     2
# Name: follow, dtype: int64
# Number of records that satisfy all rules:  2
